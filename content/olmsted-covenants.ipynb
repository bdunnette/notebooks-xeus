# %%
# Load Geopandas
import geopandas as gpd
from folium.plugins import Fullscreen, MousePosition

# %%
# Load covenants into a GeoPandas dataframe
olmsted_covenants = gpd.read_file('data/covenants-mn-olmsted-county.zip')
olmsted_covenants.head()
# Out:
#      db_id  workflow cnty_name cnty_fips  doc_num  deed_year  deed_date  \
# 0  2257221         9   Olmsted     27109  H134390       1938 1938-01-20
# 1  2257338         9   Olmsted     27109  H171567       1946 1946-10-08
# 2  2251744         9   Olmsted     27109  H135591       1938 1938-10-18
# 3  2234133         9   Olmsted     27109  H185919       1949 1949-06-27
# 4  2274119         9   Olmsted     27109  H188525       1950 1950-01-09
#
#   exec_date                                           cov_text  \
# 0       NaT  As a part of that consideration hereof the sai...
# 1       NaT  Said parcel of land shall never be owned or oc...
# 2       NaT  Subject to the express condition that said pre...
# 3       NaT  That until after December 31, 1965, said prope...
# 4       NaT  that said premises shall not at any time be co...
#
#                                               seller  ...  \
# 0                George M. Alseth and Fern L. Alseth  ...
# 1                 Wayne A. Toogood and Grace Toogood  ...
# 2      Lois N. Samelian and Aram K. Samelian, others  ...
# 3                 L. A. Fellows and Elsie G. Fellows  ...
# 4  Alfred Fratzke, Ward, Walter B. Fratzke, as gu...  ...
#
#               match_type manual_cx dt_updated zn_subj_id  zn_dt_ret  \
# 0  Long phys description      True 2025-08-08   99240404 2024-11-14
# 1  Long phys description      True 2025-08-08   98859699 2024-08-05
# 2             Simple lot      True        NaT  102893413 2025-03-24
# 3             Simple lot      True        NaT  102892847 2025-02-26
# 4             Simple lot      True 2025-07-27  109496987 2025-06-04
#
#                                            image_ids med_score plat_dbid  \
# 0                                                NaN       0.8      None
# 1  OlmstedCountyAbstracts/OldDeedBooks/D-211/H171...       1.0      None
# 2                                                NaN       0.8      None
# 3  OlmstedCountyAbstracts/OldDeedBooks/D-229/H185...       0.7      None
# 4  OlmstedCountyAbstracts/OldMiscellaneousBooks/M...       0.9      None
#
#   subd_dbid                                           geometry
# 0       NaN  POLYGON ((-92.48181 44.01656, -92.482 44.01656...
# 1       NaN  POLYGON ((-92.46867 43.99997, -92.46867 43.999...
# 2   24782.0  POLYGON ((-92.45557 44.00761, -92.45557 44.007...
# 3       NaN  POLYGON ((-92.4615 43.97786, -92.461 43.97785,...
# 4   24878.0  POLYGON ((-92.4489 44.03574, -92.44891 44.0356...
#
# [5 rows x 39 columns]

# %%
# Map the covenants on a Folium map
map = olmsted_covenants.explore()
Fullscreen().add_to(map)
MousePosition().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a3cf0fc53a9c9eeba12004874c8d75f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a3cf0fc53a9c9eeba12004874c8d75f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a3cf0fc53a9c9eeba12004874c8d75f = L.map(
#                 &quot;map_9a3cf0fc53a9c9eeba12004874c8d75f&quot;,
#                 {
#                     center: [44.01074780901895, -92.49731114471155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9a3cf0fc53a9c9eeba12004874c8d75f);
#
#
#
#
#
#             var tile_layer_40ab44432f2d1acdbdd21e0e50142956 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_40ab44432f2d1acdbdd21e0e50142956.addTo(map_9a3cf0fc53a9c9eeba12004874c8d75f);
#
#
#             map_9a3cf0fc53a9c9eeba12004874c8d75f.fitBounds(
#                 [[43.8550687964836, -92.6467469737693], [44.1664268215543, -92.3478753156538]],
#                 {}
#             );
#
#
#         function geo_json_6ac2e7bc55281f54a32882f058ae6ff7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6ac2e7bc55281f54a32882f058ae6ff7_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6ac2e7bc55281f54a32882f058ae6ff7_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_6ac2e7bc55281f54a32882f058ae6ff7_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6ac2e7bc55281f54a32882f058ae6ff7_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_6ac2e7bc55281f54a32882f058ae6ff7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6ac2e7bc55281f54a32882f058ae6ff7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6ac2e7bc55281f54a32882f058ae6ff7 = L.geoJson(null, {
#                 onEachFeature: geo_json_6ac2e7bc55281f54a32882f058ae6ff7_onEachFeature,
#
#                 style: geo_json_6ac2e7bc55281f54a32882f058ae6ff7_styler,
#                 pointToLayer: geo_json_6ac2e7bc55281f54a32882f058ae6ff7_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_6ac2e7bc55281f54a32882f058ae6ff7_add (data) {
#             geo_json_6ac2e7bc5528
